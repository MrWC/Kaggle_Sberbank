# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv("train.csv", parse_dates=['timestamp'])
test_df = pd.read_csv("test.csv")

# %%
train_df.timestamp

# %%
dtype_df = train_df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df.groupby("Column Type").aggregate('count').reset_index()
# Out:
#       Column Type  Count
# 0           int64    157
# 1  datetime64[ns]      1
# 2         float64    119
# 3          object     15

# %%
dtype_df = train_df.dtypes

# %%
dtype_df
# Out:
# id                                                int64
# timestamp                                datetime64[ns]
# full_sq                                           int64
# life_sq                                         float64
# floor                                           float64
# max_floor                                       float64
# material                                        float64
# build_year                                      float64
# num_room                                        float64
# kitch_sq                                        float64
# state                                           float64
# product_type                                     object
# sub_area                                         object
# area_m                                          float64
# raion_popul                                       int64
# green_zone_part                                 float64
# indust_part                                     float64
# children_preschool                                int64
# preschool_quota                                 float64
# preschool_education_centers_raion                 int64
# children_school                                   int64
# school_quota                                    float64
# school_education_centers_raion                    int64
# school_education_centers_top_20_raion             int64
# hospital_beds_raion                             float64
# healthcare_centers_raion                          int64
# university_top_20_raion                           int64
# sport_objects_raion                               int64
# additional_education_raion                        int64
# culture_objects_top_25                           object
#                                               ...
# big_church_count_3000                             int64
# church_count_3000                                 int64
# mosque_count_3000                                 int64
# leisure_count_3000                                int64
# sport_count_3000                                  int64
# market_count_3000                                 int64
# green_part_5000                                 float64
# prom_part_5000                                  float64
# office_count_5000                                 int64
# office_sqm_5000                                   int64
# trc_count_5000                                    int64
# trc_sqm_5000                                      int64
# cafe_count_5000                                   int64
# cafe_sum_5000_min_price_avg                     float64
# cafe_sum_5000_max_price_avg                     float64
# cafe_avg_price_5000                             float64
# cafe_count_5000_na_price                          int64
# cafe_count_5000_price_500                         int64
# cafe_count_5000_price_1000                        int64
# cafe_count_5000_price_1500                        int64
# cafe_count_5000_price_2500                        int64
# cafe_count_5000_price_4000                        int64
# cafe_count_5000_price_high                        int64
# big_church_count_5000                             int64
# church_count_5000                                 int64
# mosque_count_5000                                 int64
# leisure_count_5000                                int64
# sport_count_5000                                  int64
# market_count_5000                                 int64
# price_doc                                         int64
# dtype: object

# %%
train_df.loc[:, train_df.dtypes == 'O']
# Out:
#         product_type                   sub_area culture_objects_top_25  \
# 0         Investment                   Bibirevo                     no
# 1         Investment          Nagatinskij Zaton                    yes
# 2         Investment             Tekstil'shhiki                     no
# 3         Investment                     Mitino                     no
# 4         Investment                  Basmannoe                     no
# 5         Investment             Nizhegorodskoe                     no
# 6         Investment                 Sokol'niki                     no
# 7         Investment                   Bibirevo                     no
# 8         Investment                    Koptevo                     no
# 9         Investment                    Kuncevo                     no
# 10        Investment           Kosino-Uhtomskoe                     no
# 11        Investment          Zapadnoe Degunino                     no
# 12        Investment                    Kuncevo                     no
# 13        Investment                Presnenskoe                    yes
# 14        Investment                  Lefortovo                     no
# 15        Investment                    Mar'ino                     no
# 16        Investment                  Kuz'minki                     no
# 17        Investment                   Nagornoe                     no
# 18        Investment           Kosino-Uhtomskoe                     no
# 19        Investment                 Gol'janovo                     no
# 20        Investment                    Vnukovo                     no
# 21        Investment            Juzhnoe Tushino                     no
# 22        Investment           Severnoe Tushino                     no
# 23        Investment     Chertanovo Central'noe                     no
# 24        Investment            Juzhnoe Tushino                     no
# 25        Investment             Fili Davydkovo                     no
# 26        Investment                   Otradnoe                     no
# 27        Investment           Novo-Peredelkino                     no
# 28     OwnerOccupier                Bogorodskoe                     no
# 29        Investment               Jaroslavskoe                     no
# ...              ...                        ...                    ...
# 30441  OwnerOccupier                   Tverskoe                    yes
# 30442  OwnerOccupier    Poselenie Voskresenskoe                     no
# 30443  OwnerOccupier                   Solncevo                     no
# 30444  OwnerOccupier                     Mitino                     no
# 30445  OwnerOccupier             Filevskij Park                     no
# 30446  OwnerOccupier        Poselenie Sosenskoe                     no
# 30447  OwnerOccupier                   Solncevo                     no
# 30448  OwnerOccupier       Poselenie Moskovskij                     no
# 30449  OwnerOccupier             Filevskij Park                     no
# 30450  OwnerOccupier                   Otradnoe                     no
# 30451  OwnerOccupier  Poselenie Novofedorovskoe                     no
# 30452     Investment       Ochakovo-Matveevskoe                     no
# 30453  OwnerOccupier             Juzhnoe Butovo                     no
# 30454     Investment                Bogorodskoe                     no
# 30455  OwnerOccupier       Poselenie Vnukovskoe                     no
# 30456     Investment                     Mitino                     no
# 30457     Investment               Jaroslavskoe                     no
# 30458  OwnerOccupier       Poselenie Moskovskij                     no
# 30459  OwnerOccupier                   Solncevo                     no
# 30460     Investment                   Jasenevo                     no
# 30461     Investment               Obruchevskoe                     no
# 30462  OwnerOccupier             Filevskij Park                     no
# 30463     Investment           Severnoe Tushino                     no
# 30464  OwnerOccupier                   Sviblovo                     no
# 30465  OwnerOccupier                   Tverskoe                    yes
# 30466     Investment                   Otradnoe                     no
# 30467     Investment                   Tverskoe                    yes
# 30468  OwnerOccupier       Poselenie Vnukovskoe                     no
# 30469     Investment               Obruchevskoe                     no
# 30470     Investment                Novogireevo                     no
#
#       thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# 0                            no                 no                  no
# 1                            no                 no                  no
# 2                            no                 no                  no
# 3                            no                 no                  no
# 4                            no                 no                  no
# 5                           yes                 no                  no
# 6                            no                 no                  no
# 7                            no                 no                  no
# 8                            no                 no                  no
# 9                            no                 no                  no
# 10                           no                yes                  no
# 11                           no                 no                  no
# 12                           no                 no                  no
# 13                           no                 no                  no
# 14                           no                 no                  no
# 15                           no                 no                  no
# 16                           no                 no                  no
# 17                           no                 no                  no
# 18                           no                yes                  no
# 19                           no                 no                  no
# 20                           no                 no                  no
# 21                           no                 no                  no
# 22                           no                 no                  no
# 23                           no                 no                  no
# 24                           no                 no                  no
# 25                           no                 no                  no
# 26                           no                yes                  no
# 27                           no                 no                  no
# 28                           no                 no                  no
# 29                           no                 no                  no
# ...                         ...                ...                 ...
# 30441                        no                 no                  no
# 30442                        no                 no                  no
# 30443                        no                 no                  no
# 30444                        no                 no                  no
# 30445                        no                 no                  no
# 30446                        no                 no                  no
# 30447                        no                 no                  no
# 30448                        no                 no                  no
# 30449                        no                 no                  no
# 30450                        no                yes                  no
# 30451                        no                 no                  no
# 30452                       yes                 no                  no
# 30453                        no                 no                  no
# 30454                        no                 no                  no
# 30455                        no                 no                  no
# 30456                        no                 no                  no
# 30457                        no                 no                  no
# 30458                        no                 no                  no
# 30459                        no                 no                  no
# 30460                        no                 no                  no
# 30461                        no                 no                  no
# 30462                        no                 no                  no
# 30463                        no                 no                  no
# 30464                        no                 no                  no
# 30465                        no                 no                  no
# 30466                        no                yes                  no
# 30467                        no                 no                  no
# 30468                        no                 no                  no
# 30469                        no                 no                  no
# 30470                        no                 no                  no
#
#       radiation_raion railroad_terminal_raion big_market_raion  \
# 0                  no                      no               no
# 1                  no                      no               no
# 2                 yes                      no               no
# 3                  no                      no               no
# 4                 yes                     yes               no
# 5                 yes                      no               no
# 6                  no                      no               no
# 7                  no                      no               no
# 8                  no                      no               no
# 9                 yes                      no               no
# 10                yes                      no               no
# 11                yes                      no               no
# 12                yes                      no               no
# 13                yes                      no               no
# 14                yes                      no               no
# 15                 no                      no               no
# 16                yes                      no               no
# 17                 no                      no               no
# 18                yes                      no               no
# 19                yes                      no               no
# 20                 no                      no               no
# 21                 no                      no               no
# 22                 no                      no               no
# 23                 no                      no               no
# 24                 no                      no               no
# 25                yes                      no               no
# 26                yes                      no               no
# 27                 no                      no               no
# 28                yes                      no               no
# 29                 no                      no               no
# ...               ...                     ...              ...
# 30441             yes                     yes               no
# 30442              no                      no               no
# 30443              no                      no               no
# 30444              no                      no               no
# 30445             yes                      no               no
# 30446              no                      no              yes
# 30447              no                      no               no
# 30448              no                      no               no
# 30449             yes                      no               no
# 30450             yes                      no               no
# 30451              no                      no               no
# 30452              no                      no               no
# 30453              no                      no               no
# 30454             yes                      no               no
# 30455              no                      no               no
# 30456              no                      no               no
# 30457              no                      no               no
# 30458              no                      no               no
# 30459              no                      no               no
# 30460             yes                      no               no
# 30461             yes                      no               no
# 30462             yes                      no               no
# 30463              no                      no               no
# 30464              no                      no               no
# 30465             yes                     yes               no
# 30466             yes                      no               no
# 30467             yes                     yes               no
# 30468              no                      no               no
# 30469             yes                      no               no
# 30470             yes                      no               no
#
#       nuclear_reactor_raion detention_facility_raion water_1line  \
# 0                        no                       no          no
# 1                        no                       no          no
# 2                        no                       no          no
# 3                        no                       no          no
# 4                        no                       no          no
# 5                        no                       no          no
# 6                        no                      yes          no
# 7                        no                       no          no
# 8                        no                       no          no
# 9                        no                       no          no
# 10                       no                       no          no
# 11                       no                       no          no
# 12                       no                       no          no
# 13                       no                       no         yes
# 14                       no                      yes          no
# 15                       no                      yes          no
# 16                       no                       no          no
# 17                       no                       no          no
# 18                       no                       no          no
# 19                       no                       no          no
# 20                       no                       no          no
# 21                       no                       no          no
# 22                       no                       no          no
# 23                       no                       no          no
# 24                       no                       no         yes
# 25                       no                       no          no
# 26                       no                       no          no
# 27                       no                       no          no
# 28                       no                       no          no
# 29                       no                       no          no
# ...                     ...                      ...         ...
# 30441                    no                      yes          no
# 30442                    no                       no         yes
# 30443                    no                       no          no
# 30444                    no                       no          no
# 30445                    no                       no          no
# 30446                    no                       no          no
# 30447                    no                       no          no
# 30448                    no                       no          no
# 30449                    no                       no          no
# 30450                    no                       no          no
# 30451                    no                       no         yes
# 30452                    no                       no          no
# 30453                    no                       no          no
# 30454                    no                       no          no
# 30455                    no                       no          no
# 30456                    no                       no          no
# 30457                    no                       no          no
# 30458                    no                       no          no
# 30459                    no                       no          no
# 30460                    no                       no          no
# 30461                    no                       no          no
# 30462                    no                       no          no
# 30463                    no                       no          no
# 30464                    no                       no          no
# 30465                    no                      yes          no
# 30466                    no                       no          no
# 30467                    no                      yes          no
# 30468                    no                       no          no
# 30469                    no                       no          no
# 30470                    no                       no          no
#
#       big_road1_1line railroad_1line       ecology
# 0                  no             no          good
# 1                  no             no     excellent
# 2                  no             no          poor
# 3                  no             no          good
# 4                  no            yes     excellent
# 5                  no             no          poor
# 6                  no             no          poor
# 7                  no             no          good
# 8                  no             no          poor
# 9                  no             no  satisfactory
# 10                 no             no          good
# 11                 no             no  satisfactory
# 12                 no             no  satisfactory
# 13                 no             no          poor
# 14                 no             no          poor
# 15                 no             no     excellent
# 16                 no             no          poor
# 17                 no             no          poor
# 18                 no             no          good
# 19                 no             no          good
# 20                 no             no       no data
# 21                 no             no          poor
# 22                 no             no  satisfactory
# 23                 no             no          poor
# 24                 no             no  satisfactory
# 25                 no             no  satisfactory
# 26                 no             no          good
# 27                 no             no          good
# 28                 no             no          poor
# 29                yes             no          good
# ...               ...            ...           ...
# 30441              no             no     excellent
# 30442              no             no       no data
# 30443              no             no          good
# 30444              no             no          good
# 30445              no            yes  satisfactory
# 30446              no             no       no data
# 30447              no             no          good
# 30448              no             no       no data
# 30449              no            yes  satisfactory
# 30450              no             no          good
# 30451              no             no       no data
# 30452              no             no  satisfactory
# 30453              no             no          good
# 30454              no             no          poor
# 30455              no             no       no data
# 30456              no             no          good
# 30457              no             no          good
# 30458              no             no       no data
# 30459              no             no          good
# 30460              no             no          good
# 30461              no             no  satisfactory
# 30462              no            yes  satisfactory
# 30463              no             no  satisfactory
# 30464              no             no          poor
# 30465              no             no     excellent
# 30466              no             no          good
# 30467              no             no          poor
# 30468              no             no       no data
# 30469              no             no  satisfactory
# 30470              no             no          poor
#
# [30471 rows x 15 columns]

# %%
train_df.product_type.unique()
# Out:
# array(['Investment', 'OwnerOccupier'], dtype=object)
